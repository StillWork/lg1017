# %% [markdown]
# # tesseract를 이용한 OCR
#
# ## 사용법
# - pip install pytesseract 로 윈도우 환경에 패키지 설치
# - [tesseract.exe 설치 사이트](https://github.com/UB-Mannheim/tesseract/wiki)
# - tesseract.exe 파일을 C:\Users\사용자_이름\AppData\Local 폴더에 설치해야 함
# - PDF 파일을 이미지로 변환해야 함
#
# ## 참고
#
# - 카톡 Askup 친구추가 후 사진입력
# - [네이버 OCR](https://blog.naver.com/didim365_/222540661043)
# - [참고 블로그](https://blog.naver.com/tutmr999/222550140008)
# - [참고 블로그](https://blog.naver.com/hn03049/221957851802)

# %%
# !pip install pytesseract

# %%
# Image.open('20170622_221251.jpg')
Image.open('010146.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=789x873>

# %%
from PIL import Image
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\User\AppData\Local\tesseract.exe'
# print(pytesseract.image_to_string(Image.open('20170622_221251.jpg'), lang='kor'))
print(pytesseract.image_to_string(Image.open('010146.png'), lang='kor'))
# Out:
# 0    6    총 내용량 009
# =     -_ㅡ2      000\<히
#
# 춘'내용량당     기준치에 대한 비율
#
# 나트륨 00079                                     005%
#
# 탄수화물 009                                  005%
# 당류 009
#
# 지방 009
#
# 트랜스지방 009
# 포화지방 009
#
# 1일 영양성분 기준치에 대한 비율(%)은 2,0003!
#
# 기준이므로 개인의 필요 열량에 따라 다를 수 있습니다.
